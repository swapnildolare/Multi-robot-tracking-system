# %% [markdown]
# import cv2 import numpy as np import csv
#
# # Create a VideoCapture object
#
# cap = cv2.VideoCapture(1)
#
# # Define the Aruco dictionary
#
# aruco_dict = cv2.aruco.Dictionary_get(cv2.aruco.DICT_4X4_50)
#
# # Create the Aruco parameters
#
# aruco_params = cv2.aruco.DetectorParameters_create()
#
# # Start the loop
#
# while True: \# Capture the frame ret, frame = cap.read()
#
#     # Detect the Aruco markers in the frame
#     corners, ids, rejected = cv2.aruco.detectMarkers(frame, aruco_dict, parameters=aruco_params)
#
#     # Draw the Aruco markers on the frame
#     cv2.aruco.drawDetectedMarkers(frame, corners, ids)
#
#     # Check if any Aruco markers were detected
#     if ids is not None and len(ids) > 0:
#         # Get the x and y position of the first Aruco marker
#         x_pos = corners[0][0][0]
#         y_pos = corners[0][0][1]
#
#         # Print the ID, x and y position of the Aruco marker
#         print("arucoID",ids[0] )
#         print("x_pos:", x_pos)
#         print("y_pos:", y_pos)
#
#     # Display the frame
#     cv2.imshow("Frame", frame)
#
#     # Check if the user wants to quit
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
#
# # Release the VideoCapture and close the window
#
# cap.release() cv2.destroyAllWindows()
